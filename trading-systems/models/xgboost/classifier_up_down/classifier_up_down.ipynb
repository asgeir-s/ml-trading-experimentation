# %% [markdown]
# ## ClassifierUpDownModel

# %%
import os, sys

sys.path.insert(0, os.path.abspath("../../.."))

# %%
from models.xgboost import ClassifierUpDownModel
import pandas as pd
from pandas.plotting import scatter_matrix
from lib.data_splitter import split_features_and_target_into_train_and_test_set
from lib.data_util import load_candlesticks
from matplotlib import cm

# %%
candlesticks = load_candlesticks("BTCUSDT", "1h", custom_data_path="../../../tmp")

candlesticks
# Out:
# Closetime of newest candle is 1587038399999
# Only using data on file. Will not download new data from Binance.
#            open time     open     high      low    close       volume  \
# 0      1502942400000  4261.48  4313.62  4261.32  4308.83    47.181009
# 1      1502946000000  4308.83  4328.69  4291.37  4315.32    23.234916
# 2      1502949600000  4330.29  4345.45  4309.37  4324.35     7.229691
# 3      1502953200000  4316.62  4349.99  4287.41  4349.99     4.443249
# 4      1502956800000  4333.32  4377.85  4333.32  4360.69     0.972807
# ...              ...      ...      ...      ...      ...          ...
# 23252  1587020400000  6688.63  6818.46  6686.39  6780.00  3399.164609
# 23253  1587024000000  6893.24  6923.52  6871.13  6888.30  1641.824781
# 23254  1587027600000  7045.30  7097.00  7017.00  7027.09  4302.835917
# 23255  1587031200000  7027.70  7061.80  7026.77  7040.00  1512.420788
# 23256  1587034800000  6952.81  7049.00  6939.01  7047.83  2354.284481
#
#           close time  quote asset volume  number of trades  \
# 0      1502945999999        2.023661e+05               171
# 1      1502949599999        1.003048e+05               102
# 2      1502953199999        3.128231e+04                36
# 3      1502956799999        1.924106e+04                25
# 4      1502960399999        4.239504e+03                28
# ...              ...                 ...               ...
# 23252  1587023999999        2.300670e+07             22202
# 23253  1587027599999        1.132671e+07             12148
# 23254  1587031199999        3.038567e+07             31923
# 23255  1587034799999        1.066239e+07             12131
# 23256  1587038399999        1.645590e+07             19987
#
#        taker buy base asset volume  taker buy quote asset volume
# 0                        35.160503                  1.509525e+05
# 1                        21.448071                  9.260828e+04
# 2                         4.802861                  2.079532e+04
# 3                         2.602292                  1.129135e+04
# 4                         0.814655                  3.552747e+03
# ...                            ...                           ...
# 23252                  1901.518707                  1.285952e+07
# 23253                   873.070968                  6.024127e+06
# 23254                  2361.179694                  1.667550e+07
# 23255                   938.969209                  6.619599e+06
# 23256                  1222.918716                  8.549023e+06
#
# [23257 rows x 11 columns]

# %%
model = ClassifierUpDownModel()
features = pd.DataFrame(index=candlesticks.index)

features = model.generate_features(candlesticks, features)
target = model.generate_target(candlesticks, features)

features
# Out:
#           open     high      low    close       volume  quote asset volume  \
# 0      4261.48  4313.62  4261.32  4308.83    47.181009        2.023661e+05
# 1      4308.83  4328.69  4291.37  4315.32    23.234916        1.003048e+05
# 2      4330.29  4345.45  4309.37  4324.35     7.229691        3.128231e+04
# 3      4316.62  4349.99  4287.41  4349.99     4.443249        1.924106e+04
# 4      4333.32  4377.85  4333.32  4360.69     0.972807        4.239504e+03
# ...        ...      ...      ...      ...          ...                 ...
# 23252  6688.63  6818.46  6686.39  6780.00  3399.164609        2.300670e+07
# 23253  6893.24  6923.52  6871.13  6888.30  1641.824781        1.132671e+07
# 23254  7045.30  7097.00  7017.00  7027.09  4302.835917        3.038567e+07
# 23255  7027.70  7061.80  7026.77  7040.00  1512.420788        1.066239e+07
# 23256  6952.81  7049.00  6939.01  7047.83  2354.284481        1.645590e+07
#
#        number of trades  taker buy base asset volume  \
# 0                   171                    35.160503
# 1                   102                    21.448071
# 2                    36                     4.802861
# 3                    25                     2.602292
# 4                    28                     0.814655
# ...                 ...                          ...
# 23252             22202                  1901.518707
# 23253             12148                   873.070968
# 23254             31923                  2361.179694
# 23255             12131                   938.969209
# 23256             19987                  1222.918716
#
#        taker buy quote asset volume    volume_adi  ...  \
# 0                      1.509525e+05  3.853868e+01  ...
# 1                      9.260828e+04  4.512564e+01  ...
# 2                      2.079532e+04  4.389931e+01  ...
# 3                      1.129135e+04  4.834256e+01  ...
# 4                      3.552747e+03  4.856561e+01  ...
# ...                             ...           ...  ...
# 23252                  1.285952e+07  1.317544e+06  ...
# 23253                  6.024127e+06  1.316979e+06  ...
# 23254                  1.667550e+07  1.313761e+06  ...
# 23255                  6.619599e+06  1.313391e+06  ...
# 23256                  8.549023e+06  1.315695e+06  ...
#
#        trend-macd_signal-15_5_3  momentum_roc-2  momentum_roc-3  \
# 0                           NaN             NaN             NaN
# 1                           NaN             NaN             NaN
# 2                           NaN        0.360191             NaN
# 3                           NaN        0.803417        0.955248
# 4                           NaN        0.840358        1.051370
# ...                         ...             ...             ...
# 23252                -19.742813        2.233917        2.381502
# 23253                 11.037643        3.576917        3.866945
# 23254                 52.245233        3.644395        5.663853
# 23255                 87.307014        2.202285        3.834808
# 23256                111.538005        0.295144        2.315956
#
#        momentum_roc-5  momentum_roc-10  momentum_roc-15  momentum_roc-20  \
# 0                 NaN              NaN              NaN              NaN
# 1                 NaN              NaN              NaN              NaN
# 2                 NaN              NaN              NaN              NaN
# 3                 NaN              NaN              NaN              NaN
# 4                 NaN              NaN              NaN              NaN
# ...               ...              ...              ...              ...
# 23252        2.078917         0.781877         0.749230        -0.044228
# 23253        3.554339         2.673142         2.096383         2.601111
# 23254        6.112689         6.129517         4.132343         4.407122
# 23255        6.154391         7.102379         4.606085         4.798397
# 23256        5.975713         6.419767         4.549217         5.161671
#
#        momentum_roc-30  momentum_roc-50  momentum_roc-80
# 0                  NaN              NaN              NaN
# 1                  NaN              NaN              NaN
# 2                  NaN              NaN              NaN
# 3                  NaN              NaN              NaN
# 4                  NaN              NaN              NaN
# ...                ...              ...              ...
# 23252        -1.418526        -1.489714        -1.793073
# 23253        -0.040632         0.236611         2.522009
# 23254         1.745152         3.070212         5.005596
# 23255         2.157941         3.802045         4.732605
# 23256         2.052391         2.946040         5.577243
#
# [23257 rows x 99 columns]

# %%
target.describe()
target.value_counts()
# Out:
# 1    11979
# 0    11278
# dtype: int64

# %%
(
    training_set_features,
    training_set_targets,
    test_set_features,
    test_set_targets,
) = split_features_and_target_into_train_and_test_set(features, {0: target}, 20)

# %%
# scatte = scatter_matrix(test_set_features.iloc[:, -5:], c=test_set_target.iloc[:], s=40, hist_kwds={"bins": 15}, figsize=(20,20))

# %%
model.train(training_set_features, training_set_targets[0])
model.evaluate(test_set_features, test_set_targets[0])
# Out:
# RMSE: 0.405032
# kfold Accuracy (this only makes sense to classifyers): 78.22% (4.96%)

# %%
predictions = model.predict_dataframe(test_set_features)
df = pd.DataFrame({"target": test_set_targets[0], "prediction": predictions})
df.to_csv("./tmp/target_predictions.csv")
# Out:
# Warning: using predict_dataframe (only meant for use in evaluation). This will predict all rows in the
#             dataframe.

# %%
predictions = pd.Series(predictions)

predictions.describe()
predictions.value_counts()
# Out:
# 0    2417
# 1    2234
# dtype: int64

# %%
score = df[df["target"] == df["prediction"]]
score
# Out:
#        target  prediction
# 18606       0           0
# 18607       0           0
# 18608       0           0
# 18609       0           0
# 18610       0           0
# ...       ...         ...
# 23252       1           1
# 23253       1           1
# 23254       1           1
# 23255       1           1
# 23256       1           1
#
# [3888 rows x 2 columns]

# %%
model.print_info()

# %%
xg_boost = RegressionSklienModel(model=xgb.XGBRegressor(
    objective="reg:squarederror",
    colsample_bytree= 0.716549113595231,
    learning_rate= 0.05488437390157618,
    max_depth= 3,
    min_child_weight= 2,
    n_estimators= 181,
    subsample= 0.33243402437274977
    ))
xg_boost.train(training_set_features, training_set_targets[0])
xg_boost.evaluate(test_set_features, test_set_targets[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d2f82af7b053> in <module>
# ----> 1 xg_boost = RegressionSklienModel(model=xgb.XGBRegressor(
#       2     objective="reg:squarederror",
#       3     colsample_bytree= 0.716549113595231,
#       4     learning_rate= 0.05488437390157618,
#       5     max_depth= 3,
#
# NameError: name 'RegressionSklienModel' is not defined

# %%
predictions = xg_boost.predict_dataframe(test_set_features)
test_set_target
df = pd.DataFrame({"target": test_set_target, "prediction": predictions})
df.to_csv("./tmp/target_predictions.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-10139b682890> in <module>
# ----> 1 predictions = xg_boost.predict_dataframe(test_set_features)
#       2 test_set_target
#       3 df = pd.DataFrame({"target": test_set_target, "prediction": predictions})
#       4 df.to_csv("./tmp/target_predictions.csv")
#
# NameError: name 'test_set_features' is not defined
